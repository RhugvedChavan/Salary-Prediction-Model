# %% [markdown]
# <a href="https://colab.research.google.com/github/RhugvedChavan/Salary-Prediction-Model/blob/main/Salary_Prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Salary Prediction using Linear Regresssion

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/Salary_Data - Salary_Data.csv")
df.head(5)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.shape
# Out:
# (30, 2)

# %%
X = df.drop("Salary", axis=1)
y = df["Salary"]

# %%
model = LinearRegression()
model.fit (X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train, X_test , y_train,y_test= train_test_split(X,y,test_size=0.2 , random_state=13)

# %%
print(X_train)
print(X_test)
# Out:
#     YearsExperience
# 7               3.2
# 29             10.5
# 17              5.3
# 21              7.1
# 0               1.1
# 19              6.0
# 4               2.2
# 11              4.0
# 9               3.7
# 27              9.6
# 13              4.1
# 5               2.9
# 14              4.5
# 24              8.7
# 23              8.2
# 3               2.0
# 12              4.0
# 20              6.8
# 2               1.5
# 6               3.0
# 28             10.3
# 10              3.9
# 16              5.1
# 18              5.9
#     YearsExperience
# 22              7.9
# 15              4.9
# 26              9.5
# 1               1.3
# 25              9.0
# 8               3.2

# %%
score = model.score(X_test,y_test)
print("Model score= ",score)
# Out:
# Model score=  0.9394460269118793

# %%
new_data = pd.DataFrame({'YearsExperience':[12.6]})
prediction = model.predict(new_data)
print("Predicted Salary = ",prediction)
# Out:
# Predicted Salary =  [146968.66957731]

# %%
plt.scatter(X_test,y_test)
plt.title("Salary Prediction")
plt.xlabel("Years of Expereince")
plt.ylabel("Salary")
plt.show()

# %%
y_pred= model.predict(X_test)
print(y_pred)
# Out:
# [100978.09000057  71622.40090904 116634.45751606  36395.5739992
#  111741.84266747  54987.51042384]

# %%
plt.scatter(X_test,y_test , color="blue")
plt.plot(X_test,y_pred , color="red")
plt.title("Salary Prediction")
plt.xlabel("Years of Expereince")
plt.ylabel("Salary")
plt.show()
